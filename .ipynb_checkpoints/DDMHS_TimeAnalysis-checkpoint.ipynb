# %%
import numpy as np
import pandas as pd
import os

# %%
ddm_hs_csv = pd.read_csv("/home/jovyan/DDM Items/DDM_HS_Respondent.csv")
ddm_hs_csv.head()
# Out:
#    Assignment             Activities        Date          Time  \
# 0       92260  Fall 23 DDM HS Form D  11/15/2023  21:01:23.363
# 1       92260  Fall 23 DDM HS Form D  11/15/2023  21:01:24.047
# 2       92260  Fall 23 DDM HS Form D  11/15/2023  21:01:30.539
# 3       92260  Fall 23 DDM HS Form D  11/15/2023  21:01:31.626
# 4       92260  Fall 23 DDM HS Form D  11/15/2023  21:01:38.568
#
#                                            Action
# 0  Begin activity Fall 2023 HS DDM Administration
# 1                                   Page 1 Loaded
# 2                     Page next clicked on page 1
# 3                                   Page 2 Loaded
# 4                     Page next clicked on page 2

# %%
list(ddm_hs_csv["Activities"].unique())
# Out:
# ['Fall 23 DDM HS Form D',
#  'Fall 23 DDM HS Form C',
#  'Fall 23 DDM HS Form B',
#  'Fall 23 DDM HS Form A']

# %%
#Unique assignment values: 6192
unique = len(ddm_hs_csv["Assignment"].unique())
unique
# Out:
# 6192

# %%
#Number of Students with No End Time After Beginning Activity: 575
# Filter rows for "Begin activity" and "End activity"
begin_activities = ddm_hs_csv[ddm_hs_csv['Action'].str.contains("Begin activity")]
end_activities = ddm_hs_csv[ddm_hs_csv['Action'].str.contains("End activity")]

# Get unique Assignment IDs for both begins and ends
begin_ids = set(begin_activities['Assignment'].unique())
end_ids = set(end_activities['Assignment'].unique())

# Identify Assignment IDs that don't have an end
ids_without_end = begin_ids - end_ids
len(ids_without_end)
# Out:
# 739

# %%
#Dataframe of the IDs that don't have end activity
filtered_df = ddm_hs_csv[ddm_hs_csv["Assignment"].isin(ids_without_end)]
filtered_df
# Out:
#         Assignment             Activities        Date          Time  \
# 0            92260  Fall 23 DDM HS Form D  11/15/2023  21:01:23.363
# 1            92260  Fall 23 DDM HS Form D  11/15/2023  21:01:24.047
# 2            92260  Fall 23 DDM HS Form D  11/15/2023  21:01:30.539
# 3            92260  Fall 23 DDM HS Form D  11/15/2023  21:01:31.626
# 4            92260  Fall 23 DDM HS Form D  11/15/2023  21:01:38.568
# ...            ...                    ...         ...           ...
# 390547       90315  Fall 23 DDM HS Form B  11/08/2023  15:40:47.806
# 390548       90315  Fall 23 DDM HS Form B  11/08/2023  15:40:49.790
# 390549       90315  Fall 23 DDM HS Form B  11/08/2023  15:40:55.251
# 390550       90315  Fall 23 DDM HS Form B  11/08/2023  15:40:56.892
# 390551       90315  Fall 23 DDM HS Form B  11/08/2023  15:41:03.477
#
#                                                 Action
# 0       Begin activity Fall 2023 HS DDM Administration
# 1                                        Page 1 Loaded
# 2                          Page next clicked on page 1
# 3                                        Page 2 Loaded
# 4                          Page next clicked on page 2
# ...                                                ...
# 390547  Begin activity Fall 2023 HS DDM Administration
# 390548                                   Page 1 Loaded
# 390549                     Page next clicked on page 1
# 390550                                   Page 2 Loaded
# 390551  Pause activity Fall 2023 HS DDM Administration
#
# [22074 rows x 5 columns]

# %%
#Filtered Dataframe only showing the Assignment Numbers where the Dates are different
#for begin and end activity
def has_different_dates(group):
    begin_dates = group[group["Action"] == "Begin activity Fall 2023 HS DDM Administration"]["Date"]
    end_dates = group[group["Action"] == "End activity Fall 2023 HS DDM Administration"]["Date"]
    all_dates = pd.concat([begin_dates, end_dates]).unique()
    return len(all_dates) > 1
    
filtered_groups = ddm_hs_csv.groupby("Assignment").filter(has_different_dates)
filtered_groups
# Out:
#         Assignment             Activities        Date          Time  \
# 540          76446  Fall 23 DDM HS Form D  09/27/2023  09:05:09.044
# 541          76446  Fall 23 DDM HS Form D  09/27/2023  09:05:10.827
# 542          76446  Fall 23 DDM HS Form D  09/27/2023  09:06:05.653
# 543          76446  Fall 23 DDM HS Form D  09/27/2023  09:06:07.603
# 544          76446  Fall 23 DDM HS Form D  09/27/2023  09:06:33.945
# ...            ...                    ...         ...           ...
# 390536       90384  Fall 23 DDM HS Form A  11/15/2023  09:23:46.697
# 390537       90384  Fall 23 DDM HS Form A  11/15/2023  09:23:49.527
# 390538       90384  Fall 23 DDM HS Form A  11/15/2023  09:23:55.462
# 390539       90384  Fall 23 DDM HS Form A  11/15/2023  09:23:59.614
# 390540       90384  Fall 23 DDM HS Form A  11/15/2023  09:24:02.819
#
#                                                 Action
# 540     Begin activity Fall 2023 HS DDM Administration
# 541                                      Page 1 Loaded
# 542                        Page next clicked on page 1
# 543                                      Page 2 Loaded
# 544                        Page next clicked on page 2
# ...                                                ...
# 390536                                  Page 29 Loaded
# 390537                    Page next clicked on page 29
# 390538                                  Page 30 Loaded
# 390539                    Page next clicked on page 30
# 390540    End activity Fall 2023 HS DDM Administration
#
# [60392 rows x 5 columns]

# %%
#Number of Students with different beginning and end: 852
filtered_ddm_csv = filtered_groups[filtered_groups["Action"].isin(["Begin activity Fall 2023 HS DDM Administration", 
                                                 "End activity Fall 2023 HS DDM Administration"])]
filtered_ddm_csv
# Out:
#         Assignment             Activities        Date          Time  \
# 540          76446  Fall 23 DDM HS Form D  09/27/2023  09:05:09.044
# 613          76446  Fall 23 DDM HS Form D  10/08/2023  16:55:05.084
# 1790         87328  Fall 23 DDM HS Form A  10/30/2023  12:20:13.394
# 1858         87328  Fall 23 DDM HS Form A  11/01/2023  19:27:16.227
# 2803         79567  Fall 23 DDM HS Form A  10/06/2023  06:31:14.754
# ...            ...                    ...         ...           ...
# 389688       90228  Fall 23 DDM HS Form B  11/13/2023  06:49:34.304
# 389795       90222  Fall 23 DDM HS Form B  11/03/2023  07:33:43.423
# 389862       90222  Fall 23 DDM HS Form B  11/13/2023  18:22:56.558
# 390471       90384  Fall 23 DDM HS Form A  11/03/2023  08:53:36.718
# 390540       90384  Fall 23 DDM HS Form A  11/15/2023  09:24:02.819
#
#                                                 Action
# 540     Begin activity Fall 2023 HS DDM Administration
# 613       End activity Fall 2023 HS DDM Administration
# 1790    Begin activity Fall 2023 HS DDM Administration
# 1858      End activity Fall 2023 HS DDM Administration
# 2803    Begin activity Fall 2023 HS DDM Administration
# ...                                                ...
# 389688    End activity Fall 2023 HS DDM Administration
# 389795  Begin activity Fall 2023 HS DDM Administration
# 389862    End activity Fall 2023 HS DDM Administration
# 390471  Begin activity Fall 2023 HS DDM Administration
# 390540    End activity Fall 2023 HS DDM Administration
#
# [1705 rows x 5 columns]

# %%
#Full Dataframe of Students where their begin and end activity are different
filtered_df_2 = filtered_groups
filtered_df_2
# Out:
#         Assignment             Activities        Date          Time  \
# 540          76446  Fall 23 DDM HS Form D  09/27/2023  09:05:09.044
# 541          76446  Fall 23 DDM HS Form D  09/27/2023  09:05:10.827
# 542          76446  Fall 23 DDM HS Form D  09/27/2023  09:06:05.653
# 543          76446  Fall 23 DDM HS Form D  09/27/2023  09:06:07.603
# 544          76446  Fall 23 DDM HS Form D  09/27/2023  09:06:33.945
# ...            ...                    ...         ...           ...
# 390536       90384  Fall 23 DDM HS Form A  11/15/2023  09:23:46.697
# 390537       90384  Fall 23 DDM HS Form A  11/15/2023  09:23:49.527
# 390538       90384  Fall 23 DDM HS Form A  11/15/2023  09:23:55.462
# 390539       90384  Fall 23 DDM HS Form A  11/15/2023  09:23:59.614
# 390540       90384  Fall 23 DDM HS Form A  11/15/2023  09:24:02.819
#
#                                                 Action
# 540     Begin activity Fall 2023 HS DDM Administration
# 541                                      Page 1 Loaded
# 542                        Page next clicked on page 1
# 543                                      Page 2 Loaded
# 544                        Page next clicked on page 2
# ...                                                ...
# 390536                                  Page 29 Loaded
# 390537                    Page next clicked on page 29
# 390538                                  Page 30 Loaded
# 390539                    Page next clicked on page 30
# 390540    End activity Fall 2023 HS DDM Administration
#
# [60392 rows x 5 columns]

# %%
#Combining the two dataframes that eventually will be dropped
combined_df = pd.concat([filtered_df, filtered_df_2]).drop_duplicates()
combined_df
# Out:
#         Assignment             Activities        Date          Time  \
# 0            92260  Fall 23 DDM HS Form D  11/15/2023  21:01:23.363
# 1            92260  Fall 23 DDM HS Form D  11/15/2023  21:01:24.047
# 2            92260  Fall 23 DDM HS Form D  11/15/2023  21:01:30.539
# 3            92260  Fall 23 DDM HS Form D  11/15/2023  21:01:31.626
# 4            92260  Fall 23 DDM HS Form D  11/15/2023  21:01:38.568
# ...            ...                    ...         ...           ...
# 390536       90384  Fall 23 DDM HS Form A  11/15/2023  09:23:46.697
# 390537       90384  Fall 23 DDM HS Form A  11/15/2023  09:23:49.527
# 390538       90384  Fall 23 DDM HS Form A  11/15/2023  09:23:55.462
# 390539       90384  Fall 23 DDM HS Form A  11/15/2023  09:23:59.614
# 390540       90384  Fall 23 DDM HS Form A  11/15/2023  09:24:02.819
#
#                                                 Action
# 0       Begin activity Fall 2023 HS DDM Administration
# 1                                        Page 1 Loaded
# 2                          Page next clicked on page 1
# 3                                        Page 2 Loaded
# 4                          Page next clicked on page 2
# ...                                                ...
# 390536                                  Page 29 Loaded
# 390537                    Page next clicked on page 29
# 390538                                  Page 30 Loaded
# 390539                    Page next clicked on page 30
# 390540    End activity Fall 2023 HS DDM Administration
#
# [82466 rows x 5 columns]

# %%
#DATAFRAME OF STUDENTS AFTER DROPPING STUDENTS WHOSE BEGINNING AND END DATES ARE DIFFERENT
#AND DROPPING STUDENTS WHO DON'T HAVE AN END ACTIVITY 
#drops the rows from the dataframe containing different dates for assignments.
combined = pd.concat([ddm_hs_csv, combined_df])

result = combined.drop_duplicates(keep=False)
result
result_df = (result.reset_index()).drop("index", axis = 1)
result_df
# Out:
#         Assignment             Activities        Date          Time  \
# 0            76460  Fall 23 DDM HS Form C  09/27/2023  09:13:32.675
# 1            76460  Fall 23 DDM HS Form C  09/27/2023  09:13:34.197
# 2            76460  Fall 23 DDM HS Form C  09/27/2023  09:13:50.156
# 3            76460  Fall 23 DDM HS Form C  09/27/2023  09:13:51.850
# 4            76460  Fall 23 DDM HS Form C  09/27/2023  09:14:06.886
# ...            ...                    ...         ...           ...
# 308079       92256  Fall 23 DDM HS Form D  11/15/2023  07:07:21.257
# 308080       92256  Fall 23 DDM HS Form D  11/15/2023  07:07:25.260
# 308081       92256  Fall 23 DDM HS Form D  11/15/2023  07:07:26.953
# 308082       92256  Fall 23 DDM HS Form D  11/15/2023  07:07:29.380
# 308083       92256  Fall 23 DDM HS Form D  11/15/2023  07:07:33.000
#
#                                                 Action
# 0       Begin activity Fall 2023 HS DDM Administration
# 1                                        Page 1 Loaded
# 2                          Page next clicked on page 1
# 3                                        Page 2 Loaded
# 4                          Page next clicked on page 2
# ...                                                ...
# 308079                                  Page 31 Loaded
# 308080                    Page next clicked on page 31
# 308081                                  Page 32 Loaded
# 308082                    Page next clicked on page 32
# 308083    End activity Fall 2023 HS DDM Administration
#
# [308084 rows x 5 columns]

# %%
#Number of Students Who Paused: Using the Modified Dataframe
pause = result_df[result_df["Action"].str.contains("Pause")]
unique_pause = len(pause["Assignment"].unique())
unique_pause
# Out:
# 345

# %%
#START AND END WITH PAUSE
pause = result_df[result_df["Action"].str.contains("Pause")]
pause_df = pause.drop_duplicates(subset=['Assignment'])
pause_df
# Out:
#         Assignment             Activities        Date          Time  \
# 710          76443  Fall 23 DDM HS Form A  09/27/2023  09:49:33.456
# 1633         87335  Fall 23 DDM HS Form C  11/02/2023  06:57:07.111
# 3109         80586  Fall 23 DDM HS Form D  10/11/2023  09:10:15.047
# 3348         76465  Fall 23 DDM HS Form C  09/27/2023  09:13:48.153
# 3441         80604  Fall 23 DDM HS Form B  10/11/2023  09:10:15.467
# ...            ...                    ...         ...           ...
# 305927       92087  Fall 23 DDM HS Form B  11/09/2023  10:55:13.565
# 307213       92192  Fall 23 DDM HS Form C  11/10/2023  11:01:06.814
# 307370       92213  Fall 23 DDM HS Form A  11/13/2023  22:07:40.098
# 307475       91928  Fall 23 DDM HS Form A  11/30/2023  08:09:46.864
# 307797       92250  Fall 23 DDM HS Form B  11/15/2023  07:07:56.061
#
#                                                 Action
# 710     Pause activity Fall 2023 HS DDM Administration
# 1633    Pause activity Fall 2023 HS DDM Administration
# 3109    Pause activity Fall 2023 HS DDM Administration
# 3348    Pause activity Fall 2023 HS DDM Administration
# 3441    Pause activity Fall 2023 HS DDM Administration
# ...                                                ...
# 305927  Pause activity Fall 2023 HS DDM Administration
# 307213  Pause activity Fall 2023 HS DDM Administration
# 307370  Pause activity Fall 2023 HS DDM Administration
# 307475  Pause activity Fall 2023 HS DDM Administration
# 307797  Pause activity Fall 2023 HS DDM Administration
#
# [345 rows x 5 columns]

# %%
assignments_to_exclude = pause_df['Assignment']

# Filter out rows in result_df where 'Assignment' numbers appear in pause_df
filtered_result_df = result_df[~result_df['Assignment'].isin(assignments_to_exclude)]
filter_result_df = (filtered_result_df.reset_index()).drop("index", axis = 1)
filter_result_df
# Out:
#         Assignment             Activities        Date          Time  \
# 0            76460  Fall 23 DDM HS Form C  09/27/2023  09:13:32.675
# 1            76460  Fall 23 DDM HS Form C  09/27/2023  09:13:34.197
# 2            76460  Fall 23 DDM HS Form C  09/27/2023  09:13:50.156
# 3            76460  Fall 23 DDM HS Form C  09/27/2023  09:13:51.850
# 4            76460  Fall 23 DDM HS Form C  09/27/2023  09:14:06.886
# ...            ...                    ...         ...           ...
# 283920       92256  Fall 23 DDM HS Form D  11/15/2023  07:07:21.257
# 283921       92256  Fall 23 DDM HS Form D  11/15/2023  07:07:25.260
# 283922       92256  Fall 23 DDM HS Form D  11/15/2023  07:07:26.953
# 283923       92256  Fall 23 DDM HS Form D  11/15/2023  07:07:29.380
# 283924       92256  Fall 23 DDM HS Form D  11/15/2023  07:07:33.000
#
#                                                 Action
# 0       Begin activity Fall 2023 HS DDM Administration
# 1                                        Page 1 Loaded
# 2                          Page next clicked on page 1
# 3                                        Page 2 Loaded
# 4                          Page next clicked on page 2
# ...                                                ...
# 283920                                  Page 31 Loaded
# 283921                    Page next clicked on page 31
# 283922                                  Page 32 Loaded
# 283923                    Page next clicked on page 32
# 283924    End activity Fall 2023 HS DDM Administration
#
# [283925 rows x 5 columns]

# %%
#Number of students who never paused on the same day
unique_filter = len(filter_result_df["Assignment"].unique())
unique_filter
# Out:
# 4256

# %%
#Number of Students Who Paused: Using the Modified Dataframe
pause = result_df[result_df["Action"].str.contains("Pause")]
unique_pause = len(pause["Assignment"].unique())
unique_pause
# Out:
# 345

# %%
#ONE SITTING (NO PAUSE) 
#Looking at Completion Times after dropping data with different Begin and End, and no pause
filter_result_df['DateTime'] = pd.to_datetime(filter_result_df['Date'] + ' ' + filter_result_df['Time'])

completion_times = []

for assignment, group in filter_result_df.groupby('Assignment'):
    begin_activity = group[group['Action'] == "Begin activity Fall 2023 HS DDM Administration"]['DateTime']
    end_activity = group[group['Action'] == "End activity Fall 2023 HS DDM Administration"]['DateTime']
    activity_name = group['Activities'].iloc[0]
    
    if not begin_activity.empty and not end_activity.empty:
        start_time = begin_activity.iloc[0]
        end_time = end_activity.iloc[0]
        
        completion_time = end_time - start_time
        completion_times.append((assignment, completion_time, activity_name))

pause_times_df = pd.DataFrame(completion_times, columns=['Assignment', 'Completion Time', 'Activities'])
pause_times_df
# Out:
#       Assignment        Completion Time             Activities
# 0          74882 0 days 00:52:43.433000  Fall 23 DDM HS Form B
# 1          74900 0 days 00:17:21.641000  Fall 23 DDM HS Form D
# 2          74901 0 days 00:19:35.946000  Fall 23 DDM HS Form A
# 3          74902 0 days 02:48:21.817000  Fall 23 DDM HS Form B
# 4          74903 0 days 00:40:27.084000  Fall 23 DDM HS Form C
# ...          ...                    ...                    ...
# 4251       93208 0 days 00:59:21.755000  Fall 23 DDM HS Form A
# 4252       93210 0 days 00:52:34.237000  Fall 23 DDM HS Form C
# 4253       93230 0 days 04:55:43.968000  Fall 23 DDM HS Form D
# 4254       93231 0 days 00:04:59.207000  Fall 23 DDM HS Form C
# 4255       93233 0 days 00:41:48.811000  Fall 23 DDM HS Form B
#
# [4256 rows x 3 columns]

# %%
filtered_pause_times = pause_times_df.sort_values(by="Completion Time", ascending = False)
filtered_pause_time = (filtered_pause_times.reset_index()).drop("index", axis = 1)
filtered_pause_time
# Out:
#       Assignment        Completion Time             Activities
# 0          92132 0 days 15:50:05.286000  Fall 23 DDM HS Form B
# 1          88358 0 days 15:17:54.807000  Fall 23 DDM HS Form A
# 2          92714 0 days 15:02:14.686000  Fall 23 DDM HS Form B
# 3          88382 0 days 14:51:34.730000  Fall 23 DDM HS Form D
# 4          92705 0 days 14:25:10.865000  Fall 23 DDM HS Form A
# ...          ...                    ...                    ...
# 4251       91670 0 days 00:04:02.743000  Fall 23 DDM HS Form D
# 4252       91499 0 days 00:04:00.138000  Fall 23 DDM HS Form A
# 4253       79811 0 days 00:03:55.485000  Fall 23 DDM HS Form A
# 4254       90987 0 days 00:03:52.547000  Fall 23 DDM HS Form C
# 4255       78791 0 days 00:03:26.151000  Fall 23 DDM HS Form C
#
# [4256 rows x 3 columns]

# %%
form_pause_a = filtered_pause_time[filtered_pause_time["Activities"] == "Fall 23 DDM HS Form A"]
form_pause_a
# Out:
#       Assignment        Completion Time             Activities
# 1          88358 0 days 15:17:54.807000  Fall 23 DDM HS Form A
# 4          92705 0 days 14:25:10.865000  Fall 23 DDM HS Form A
# 7          92718 0 days 13:20:50.462000  Fall 23 DDM HS Form A
# 8          85339 0 days 13:05:55.584000  Fall 23 DDM HS Form A
# 21         90961 0 days 11:53:44.948000  Fall 23 DDM HS Form A
# ...          ...                    ...                    ...
# 4242       84577 0 days 00:04:32.089000  Fall 23 DDM HS Form A
# 4244       83294 0 days 00:04:30.947000  Fall 23 DDM HS Form A
# 4250       79518 0 days 00:04:03.992000  Fall 23 DDM HS Form A
# 4252       91499 0 days 00:04:00.138000  Fall 23 DDM HS Form A
# 4253       79811 0 days 00:03:55.485000  Fall 23 DDM HS Form A
#
# [1084 rows x 3 columns]

# %%
form_pause_b = filtered_pause_time[filtered_pause_time["Activities"] == "Fall 23 DDM HS Form B"]
form_pause_b
# Out:
#       Assignment        Completion Time             Activities
# 0          92132 0 days 15:50:05.286000  Fall 23 DDM HS Form B
# 2          92714 0 days 15:02:14.686000  Fall 23 DDM HS Form B
# 6          92677 0 days 13:22:14.606000  Fall 23 DDM HS Form B
# 18         75820 0 days 12:14:17.334000  Fall 23 DDM HS Form B
# 19         78128 0 days 12:08:57.427000  Fall 23 DDM HS Form B
# ...          ...                    ...                    ...
# 4233       92774 0 days 00:04:58.724000  Fall 23 DDM HS Form B
# 4240       86620 0 days 00:04:36.886000  Fall 23 DDM HS Form B
# 4241       89725 0 days 00:04:32.750000  Fall 23 DDM HS Form B
# 4245       80859 0 days 00:04:28.913000  Fall 23 DDM HS Form B
# 4248       90084 0 days 00:04:07.643000  Fall 23 DDM HS Form B
#
# [1063 rows x 3 columns]

# %%
form_pause_c = filtered_pause_time[filtered_pause_time["Activities"] == "Fall 23 DDM HS Form C"]
form_pause_c
# Out:
#       Assignment        Completion Time             Activities
# 5          82745 0 days 13:43:26.829000  Fall 23 DDM HS Form C
# 9          78742 0 days 12:58:04.482000  Fall 23 DDM HS Form C
# 11         92771 0 days 12:51:08.103000  Fall 23 DDM HS Form C
# 12         76394 0 days 12:50:38.364000  Fall 23 DDM HS Form C
# 14         89379 0 days 12:42:42.681000  Fall 23 DDM HS Form C
# ...          ...                    ...                    ...
# 4235       91873 0 days 00:04:51.210000  Fall 23 DDM HS Form C
# 4238       79386 0 days 00:04:39.090000  Fall 23 DDM HS Form C
# 4243       79794 0 days 00:04:31.044000  Fall 23 DDM HS Form C
# 4254       90987 0 days 00:03:52.547000  Fall 23 DDM HS Form C
# 4255       78791 0 days 00:03:26.151000  Fall 23 DDM HS Form C
#
# [1031 rows x 3 columns]

# %%
form_pause_d = filtered_pause_time[filtered_pause_time["Activities"] == "Fall 23 DDM HS Form D"]
form_pause_d
# Out:
#       Assignment        Completion Time             Activities
# 3          88382 0 days 14:51:34.730000  Fall 23 DDM HS Form D
# 10         82718 0 days 12:52:26.269000  Fall 23 DDM HS Form D
# 13         92691 0 days 12:44:04.489000  Fall 23 DDM HS Form D
# 15         92695 0 days 12:31:24.712000  Fall 23 DDM HS Form D
# 16         83186 0 days 12:22:31.665000  Fall 23 DDM HS Form D
# ...          ...                    ...                    ...
# 4234       90059 0 days 00:04:52.542000  Fall 23 DDM HS Form D
# 4246       88070 0 days 00:04:14.637000  Fall 23 DDM HS Form D
# 4247       91231 0 days 00:04:09.798000  Fall 23 DDM HS Form D
# 4249       76249 0 days 00:04:05.626000  Fall 23 DDM HS Form D
# 4251       91670 0 days 00:04:02.743000  Fall 23 DDM HS Form D
#
# [1078 rows x 3 columns]

# %%
form_pause_a.describe()
# Out:
#          Assignment            Completion Time
# count   1084.000000                       1084
# mean   84557.124539  0 days 00:44:45.693574723
# std     5756.297473  0 days 01:22:30.008062560
# min    74901.000000     0 days 00:03:55.485000
# 25%    79525.500000     0 days 00:20:25.785500
# 50%    84477.000000     0 days 00:29:07.944000
# 75%    90279.250000     0 days 00:38:29.467500
# max    93208.000000     0 days 15:17:54.807000

# %%
form_pause_a["Completion Time"].median()
# Out:
# Timedelta('0 days 00:29:07.944000')

# %%
a_percentile_90 = form_pause_a["Completion Time"].quantile(0.9)
a_percentile_90
# Out:
# Timedelta('0 days 01:00:03.821200')

# %%
form_pause_b.describe()
# Out:
#          Assignment            Completion Time
# count   1063.000000                       1063
# mean   84665.747883  0 days 00:42:31.769600188
# std     5814.056498  0 days 01:19:10.440356625
# min    74882.000000     0 days 00:04:07.643000
# 25%    79554.000000     0 days 00:20:40.792000
# 50%    84576.000000     0 days 00:28:28.424000
# 75%    90392.000000     0 days 00:38:06.838500
# max    93233.000000     0 days 15:50:05.286000

# %%
form_pause_b["Completion Time"].median()
# Out:
# Timedelta('0 days 00:28:28.424000')

# %%
b_percentile_90 = form_pause_b["Completion Time"].quantile(0.9)
b_percentile_90
# Out:
# Timedelta('0 days 00:55:42.140200')

# %%
form_pause_c.describe()
# Out:
#          Assignment            Completion Time
# count   1031.000000                       1031
# mean   84809.512124  0 days 00:44:39.668900096
# std     5706.904888  0 days 01:22:05.969255040
# min    74903.000000     0 days 00:03:26.151000
# 25%    79716.000000     0 days 00:22:04.168000
# 50%    84560.000000     0 days 00:29:51.397000
# 75%    90380.500000     0 days 00:39:47.673000
# max    93231.000000     0 days 13:43:26.829000

# %%
form_pause_c["Completion Time"].median()
# Out:
# Timedelta('0 days 00:29:51.397000')

# %%
c_percentile_90 = form_pause_c["Completion Time"].quantile(0.9)
c_percentile_90
# Out:
# Timedelta('0 days 00:56:45.655000')

# %%
form_pause_d.describe()
# Out:
#          Assignment            Completion Time
# count   1078.000000                       1078
# mean   84699.300557  0 days 00:45:48.004032467
# std     5763.398022  0 days 01:26:15.198961140
# min    74900.000000     0 days 00:04:02.743000
# 25%    79624.750000     0 days 00:21:43.248250
# 50%    84538.000000     0 days 00:29:45.725000
# 75%    90401.000000     0 days 00:40:04.346500
# max    93230.000000     0 days 14:51:34.730000

# %%
form_pause_d["Completion Time"].median()
# Out:
# Timedelta('0 days 00:29:45.725000')

# %%
d_percentile_90 = form_pause_d["Completion Time"].quantile(0.9)
d_percentile_90
# Out:
# Timedelta('0 days 00:56:06.038300')

# %%
#NO PAUSE Boxplot of Form A & B: Using Melinee's Code to have similar boxplot style
import matplotlib.pyplot as plt

just_pause_and_ct = filtered_pause_time[['Activities','Completion Time']].reset_index()
just_pause_and_ct['Completion Time'] = [td.total_seconds()/3600 for td in just_pause_and_ct['Completion Time']]
just_pause_and_ct.boxplot(column = 'Completion Time', by = 'Activities', figsize=(12,4), vert=False)
#plt.title('Completion Times per Activity')
plt.xlabel('Completion Time in Hours')
plt.axvline(x=1, color='b', linestyle='--', label='1 Hour Mark')
plt.ylabel('Activities')
plt.show()

# %%
#Looking at Completion Times after dropping data with different Begin and End, and no end
result_df['DateTime'] = pd.to_datetime(result_df['Date'] + ' ' + result_df['Time'])

completion_times = []

for assignment, group in result_df.groupby('Assignment'):
    begin_activity = group[group['Action'] == "Begin activity Fall 2023 HS DDM Administration"]['DateTime']
    end_activity = group[group['Action'] == "End activity Fall 2023 HS DDM Administration"]['DateTime']
    activity_name = group['Activities'].iloc[0]
    
    if not begin_activity.empty and not end_activity.empty:
        start_time = begin_activity.iloc[0]
        end_time = end_activity.iloc[0]
        
        completion_time = end_time - start_time
        completion_times.append((assignment, completion_time, activity_name))

completion_times_df = pd.DataFrame(completion_times, columns=['Assignment', 'Completion Time', 'Activities'])
completion_times_df
# Out:
#       Assignment        Completion Time             Activities
# 0          74882 0 days 00:52:43.433000  Fall 23 DDM HS Form B
# 1          74900 0 days 00:17:21.641000  Fall 23 DDM HS Form D
# 2          74901 0 days 00:19:35.946000  Fall 23 DDM HS Form A
# 3          74902 0 days 02:48:21.817000  Fall 23 DDM HS Form B
# 4          74903 0 days 00:40:27.084000  Fall 23 DDM HS Form C
# ...          ...                    ...                    ...
# 4596       93208 0 days 00:59:21.755000  Fall 23 DDM HS Form A
# 4597       93210 0 days 00:52:34.237000  Fall 23 DDM HS Form C
# 4598       93230 0 days 04:55:43.968000  Fall 23 DDM HS Form D
# 4599       93231 0 days 00:04:59.207000  Fall 23 DDM HS Form C
# 4600       93233 0 days 00:41:48.811000  Fall 23 DDM HS Form B
#
# [4601 rows x 3 columns]

# %%
#Dataframe of the sorted times between start and end of activity
filtered_times = completion_times_df.sort_values(by="Completion Time", ascending = False)
filtered_comp_time = (filtered_times.reset_index()).drop("index", axis = 1)
filtered_comp_time
# Out:
#       Assignment        Completion Time             Activities
# 0          89185 0 days 20:43:14.446000  Fall 23 DDM HS Form B
# 1          90905 0 days 16:05:41.683000  Fall 23 DDM HS Form D
# 2          90814 0 days 15:50:33.466000  Fall 23 DDM HS Form C
# 3          92132 0 days 15:50:05.286000  Fall 23 DDM HS Form B
# 4          85003 0 days 15:37:16.756000  Fall 23 DDM HS Form C
# ...          ...                    ...                    ...
# 4596       91670 0 days 00:04:02.743000  Fall 23 DDM HS Form D
# 4597       91499 0 days 00:04:00.138000  Fall 23 DDM HS Form A
# 4598       79811 0 days 00:03:55.485000  Fall 23 DDM HS Form A
# 4599       90987 0 days 00:03:52.547000  Fall 23 DDM HS Form C
# 4600       78791 0 days 00:03:26.151000  Fall 23 DDM HS Form C
#
# [4601 rows x 3 columns]

# %%
form_a = filtered_comp_time[filtered_comp_time["Activities"] == "Fall 23 DDM HS Form A"]
form_a
# Out:
#       Assignment        Completion Time             Activities
# 6          88358 0 days 15:17:54.807000  Fall 23 DDM HS Form A
# 8          83240 0 days 14:52:42.070000  Fall 23 DDM HS Form A
# 10         92705 0 days 14:25:10.865000  Fall 23 DDM HS Form A
# 12         87530 0 days 13:58:11.809000  Fall 23 DDM HS Form A
# 16         92718 0 days 13:20:50.462000  Fall 23 DDM HS Form A
# ...          ...                    ...                    ...
# 4587       84577 0 days 00:04:32.089000  Fall 23 DDM HS Form A
# 4589       83294 0 days 00:04:30.947000  Fall 23 DDM HS Form A
# 4595       79518 0 days 00:04:03.992000  Fall 23 DDM HS Form A
# 4597       91499 0 days 00:04:00.138000  Fall 23 DDM HS Form A
# 4598       79811 0 days 00:03:55.485000  Fall 23 DDM HS Form A
#
# [1171 rows x 3 columns]

# %%
form_a.describe()
# Out:
#          Assignment            Completion Time
# count   1171.000000                       1171
# mean   84694.117848  0 days 00:54:35.938245943
# std     5759.391555  0 days 01:45:46.976670522
# min    74901.000000     0 days 00:03:55.485000
# 25%    79592.500000     0 days 00:20:59.505000
# 50%    84550.000000     0 days 00:29:54.696000
# 75%    90404.000000     0 days 00:41:32.100500
# max    93208.000000     0 days 15:17:54.807000

# %%
form_a_median = form_a["Completion Time"].median()
form_a_median
# Out:
# Timedelta('0 days 00:29:54.696000')

# %%
form_b = filtered_comp_time[filtered_comp_time["Activities"] == "Fall 23 DDM HS Form B"]
form_b
# Out:
#       Assignment        Completion Time             Activities
# 0          89185 0 days 20:43:14.446000  Fall 23 DDM HS Form B
# 3          92132 0 days 15:50:05.286000  Fall 23 DDM HS Form B
# 5          83528 0 days 15:20:41.478000  Fall 23 DDM HS Form B
# 7          92714 0 days 15:02:14.686000  Fall 23 DDM HS Form B
# 11         91532 0 days 14:08:12.862000  Fall 23 DDM HS Form B
# ...          ...                    ...                    ...
# 4578       92774 0 days 00:04:58.724000  Fall 23 DDM HS Form B
# 4585       86620 0 days 00:04:36.886000  Fall 23 DDM HS Form B
# 4586       89725 0 days 00:04:32.750000  Fall 23 DDM HS Form B
# 4590       80859 0 days 00:04:28.913000  Fall 23 DDM HS Form B
# 4593       90084 0 days 00:04:07.643000  Fall 23 DDM HS Form B
#
# [1152 rows x 3 columns]

# %%
form_b.describe()
# Out:
#          Assignment            Completion Time
# count   1152.000000                       1152
# mean   84737.423611  0 days 00:52:38.168905381
# std     5811.545195  0 days 01:47:08.917355899
# min    74882.000000     0 days 00:04:07.643000
# 25%    79588.000000     0 days 00:21:21.875000
# 50%    84590.000000     0 days 00:29:26.079000
# 75%    90411.250000     0 days 00:40:49.735000
# max    93233.000000     0 days 20:43:14.446000

# %%
form_b_median = form_b["Completion Time"].median()
form_b_median
# Out:
# Timedelta('0 days 00:29:26.079000')

# %%
form_c = filtered_comp_time[filtered_comp_time["Activities"] == "Fall 23 DDM HS Form C"]
form_c
# Out:
#       Assignment        Completion Time             Activities
# 2          90814 0 days 15:50:33.466000  Fall 23 DDM HS Form C
# 4          85003 0 days 15:37:16.756000  Fall 23 DDM HS Form C
# 13         82745 0 days 13:43:26.829000  Fall 23 DDM HS Form C
# 14         80536 0 days 13:32:51.649000  Fall 23 DDM HS Form C
# 19         78742 0 days 12:58:04.482000  Fall 23 DDM HS Form C
# ...          ...                    ...                    ...
# 4580       91873 0 days 00:04:51.210000  Fall 23 DDM HS Form C
# 4583       79386 0 days 00:04:39.090000  Fall 23 DDM HS Form C
# 4588       79794 0 days 00:04:31.044000  Fall 23 DDM HS Form C
# 4599       90987 0 days 00:03:52.547000  Fall 23 DDM HS Form C
# 4600       78791 0 days 00:03:26.151000  Fall 23 DDM HS Form C
#
# [1122 rows x 3 columns]

# %%
form_c.describe()
# Out:
#         Assignment            Completion Time
# count   1122.00000                       1122
# mean   84802.22549  0 days 00:54:29.027144385
# std     5754.15690  0 days 01:45:47.564323488
# min    74903.00000     0 days 00:03:26.151000
# 25%    79626.25000     0 days 00:22:25.184000
# 50%    84569.00000     0 days 00:30:46.156500
# 75%    90407.50000     0 days 00:41:43.490000
# max    93231.00000     0 days 15:50:33.466000

# %%
form_c_median = form_c["Completion Time"].median()
form_c_median
# Out:
# Timedelta('0 days 00:30:46.156500')

# %%
form_d = filtered_comp_time[filtered_comp_time["Activities"] == "Fall 23 DDM HS Form D"]
form_d
# Out:
#       Assignment        Completion Time             Activities
# 1          90905 0 days 16:05:41.683000  Fall 23 DDM HS Form D
# 9          88382 0 days 14:51:34.730000  Fall 23 DDM HS Form D
# 20         82718 0 days 12:52:26.269000  Fall 23 DDM HS Form D
# 23         92691 0 days 12:44:04.489000  Fall 23 DDM HS Form D
# 25         92695 0 days 12:31:24.712000  Fall 23 DDM HS Form D
# ...          ...                    ...                    ...
# 4579       90059 0 days 00:04:52.542000  Fall 23 DDM HS Form D
# 4591       88070 0 days 00:04:14.637000  Fall 23 DDM HS Form D
# 4592       91231 0 days 00:04:09.798000  Fall 23 DDM HS Form D
# 4594       76249 0 days 00:04:05.626000  Fall 23 DDM HS Form D
# 4596       91670 0 days 00:04:02.743000  Fall 23 DDM HS Form D
#
# [1156 rows x 3 columns]

# %%
form_d.describe()
# Out:
#          Assignment            Completion Time
# count   1156.000000                       1156
# mean   84743.826990  0 days 00:53:49.417737024
# std     5753.585545  0 days 01:45:30.015939991
# min    74900.000000     0 days 00:04:02.743000
# 25%    79643.500000     0 days 00:22:13.924750
# 50%    84559.000000     0 days 00:30:34.898500
# 75%    90405.000000     0 days 00:41:18.654000
# max    93230.000000     0 days 16:05:41.683000

# %%
form_d_median = form_d["Completion Time"].median()
form_d_median
# Out:
# Timedelta('0 days 00:30:34.898500')

# %%
filtered_comp_time['Activities'] = filtered_comp_time['Activities'].str.extract('(HS Form [ABCD])')
filtered_comp_time
# Out:
#       Assignment        Completion Time Activities
# 0          89185 0 days 20:43:14.446000  HS Form B
# 1          90905 0 days 16:05:41.683000  HS Form D
# 2          90814 0 days 15:50:33.466000  HS Form C
# 3          92132 0 days 15:50:05.286000  HS Form B
# 4          85003 0 days 15:37:16.756000  HS Form C
# ...          ...                    ...        ...
# 4596       91670 0 days 00:04:02.743000  HS Form D
# 4597       91499 0 days 00:04:00.138000  HS Form A
# 4598       79811 0 days 00:03:55.485000  HS Form A
# 4599       90987 0 days 00:03:52.547000  HS Form C
# 4600       78791 0 days 00:03:26.151000  HS Form C
#
# [4601 rows x 3 columns]

# %%
#Boxplot of Form A, B, C, D: Using Melinee's Code to have similar boxplot style
import matplotlib.pyplot as plt

just_act_and_ct = filtered_comp_time[['Activities','Completion Time']].reset_index()
just_act_and_ct['Completion Time'] = [td.total_seconds()/3600 for td in just_act_and_ct['Completion Time']]
just_act_and_ct.boxplot(column = 'Completion Time', by = 'Activities', figsize=(12,4), vert=False)
plt.title('Completion Times per Activity')
plt.xlabel('Completion Time in Hours')
plt.axvline(x=1, color='b', linestyle='--', label='1 Hour Mark')
plt.ylabel('Activities')
plt.show()
