# %%
import numpy as np
import pandas as pd

# %%
import os

# %%
print(os.getcwd())
# Out:
# /home/jovyan/DDM Items

# %%
files_and_directories = os.listdir('/home/jovyan')
files_and_directories
# Out:
# ['.cache',
#  'DDM Items',
#  'Untitled1.ipynb',
#  'fa23-student.git',
#  '.config',
#  '.ploomber',
#  'shared',
#  'fa23-student',
#  'Untitled2.ipynb',
#  '.ipython',
#  'Untitled.ipynb',
#  '.jupyter',
#  '.npm',
#  '.ipynb_checkpoints',
#  '.local']

# %%
ddm_ms_csv = pd.read_csv("/home/jovyan/DDM Items/DDM_Respondent.csv")
ddm_ms_csv.head()
# Out:
#    Assignment             Activities        Date          Time  \
# 0       78738  Fall 23 DDM MS Form B  10/03/2023  07:04:18.415
# 1       78738  Fall 23 DDM MS Form B  10/03/2023  07:04:19.771
# 2       78738  Fall 23 DDM MS Form B  10/03/2023  07:04:30.293
# 3       78738  Fall 23 DDM MS Form B  10/03/2023  07:04:31.888
# 4       78738  Fall 23 DDM MS Form B  10/03/2023  07:04:48.403
#
#                                            Action
# 0  Begin activity Fall 2023 MS DDM Administration
# 1                                   Page 1 Loaded
# 2                     Page next clicked on page 1
# 3                                   Page 2 Loaded
# 4                     Page next clicked on page 2

# %%
#Total number of rows
len(ddm_ms_csv)
# Out:
# 119677

# %%
#Unique assignment values: 3237
unique = len(ddm_ms_csv["Assignment"].unique())
unique
# Out:
# 3237

# %%
#Number of Students with No End Time After Beginning Activity: 575
# Filter rows for "Begin activity" and "End activity"
begin_activities = ddm_ms_csv[ddm_ms_csv['Action'].str.contains("Begin activity")]
end_activities = ddm_ms_csv[ddm_ms_csv['Action'].str.contains("End activity")]

# Get unique Assignment IDs for both begins and ends
begin_ids = set(begin_activities['Assignment'].unique())
end_ids = set(end_activities['Assignment'].unique())

# Identify Assignment IDs that don't have an end
ids_without_end = begin_ids - end_ids
len(ids_without_end)
# Out:
# 575

# %%
#Dataframe of the IDs that don't have end activity
filtered_df = ddm_ms_csv[ddm_ms_csv["Assignment"].isin(ids_without_end)]
filtered_df
# Out:
#         Assignment             Activities        Date          Time  \
# 74           83978  Fall 23 DDM MS Form B  10/23/2023  07:12:18.301
# 75           83978  Fall 23 DDM MS Form B  10/23/2023  07:12:18.661
# 76           83978  Fall 23 DDM MS Form B  10/23/2023  07:12:25.966
# 77           83978  Fall 23 DDM MS Form B  10/23/2023  07:12:26.631
# 78           83978  Fall 23 DDM MS Form B  10/23/2023  07:12:43.755
# ...            ...                    ...         ...           ...
# 119475       92014  Fall 23 DDM MS Form B  11/09/2023  05:39:22.526
# 119476       92014  Fall 23 DDM MS Form B  11/09/2023  05:42:03.543
# 119477       92014  Fall 23 DDM MS Form B  11/09/2023  05:42:06.306
# 119478       92014  Fall 23 DDM MS Form B  11/09/2023  05:42:19.637
# 119479       92014  Fall 23 DDM MS Form B  11/09/2023  05:42:23.509
#
#                                                 Action
# 74      Begin activity Fall 2023 MS DDM Administration
# 75                                       Page 1 Loaded
# 76                         Page next clicked on page 1
# 77                                       Page 2 Loaded
# 78                         Page next clicked on page 2
# ...                                                ...
# 119475                                   Page 5 Loaded
# 119476                     Page next clicked on page 5
# 119477                                   Page 6 Loaded
# 119478                     Page next clicked on page 6
# 119479                                   Page 7 Loaded
#
# [12163 rows x 5 columns]

# %%
#Filtered Dataframe only showing the Assignment Numbers where the Dates are different
#for begin and end activity
def has_different_dates(group):
    begin_dates = group[group["Action"] == "Begin activity Fall 2023 MS DDM Administration"]["Date"]
    end_dates = group[group["Action"] == "End activity Fall 2023 MS DDM Administration"]["Date"]
    all_dates = pd.concat([begin_dates, end_dates]).unique()
    return len(all_dates) > 1
    
filtered_groups = ddm_ms_csv.groupby("Assignment").filter(has_different_dates)
filtered_groups
# Out:
#         Assignment             Activities        Date          Time  \
# 180          74955  Fall 23 DDM MS Form A  09/25/2023  06:21:51.608
# 181          74955  Fall 23 DDM MS Form A  09/25/2023  06:21:53.166
# 182          74955  Fall 23 DDM MS Form A  09/25/2023  06:24:25.468
# 183          74955  Fall 23 DDM MS Form A  09/25/2023  06:24:27.165
# 184          74955  Fall 23 DDM MS Form A  09/25/2023  06:24:46.620
# ...            ...                    ...         ...           ...
# 116153       89775  Fall 23 DDM MS Form A  11/07/2023  11:08:35.644
# 116154       89775  Fall 23 DDM MS Form A  11/07/2023  11:09:23.436
# 116155       89775  Fall 23 DDM MS Form A  11/07/2023  11:09:25.958
# 116156       89775  Fall 23 DDM MS Form A  11/07/2023  11:09:33.793
# 116157       89775  Fall 23 DDM MS Form A  11/07/2023  11:09:38.247
#
#                                                 Action
# 180     Begin activity Fall 2023 MS DDM Administration
# 181                                      Page 1 Loaded
# 182                        Page next clicked on page 1
# 183                                      Page 2 Loaded
# 184                        Page next clicked on page 2
# ...                                                ...
# 116153                                  Page 17 Loaded
# 116154                    Page next clicked on page 17
# 116155                                  Page 18 Loaded
# 116156                    Page next clicked on page 18
# 116157    End activity Fall 2023 MS DDM Administration
#
# [18332 rows x 5 columns]

# %%
#Number of Students with different beginning and end: 421
filtered_ddm_csv = filtered_groups[filtered_groups["Action"].isin(["Begin activity Fall 2023 MS DDM Administration", 
                                                 "End activity Fall 2023 MS DDM Administration"])]
filtered_ddm_csv
# Out:
#         Assignment             Activities        Date          Time  \
# 180          74955  Fall 23 DDM MS Form A  09/25/2023  06:21:51.608
# 221          74955  Fall 23 DDM MS Form A  09/26/2023  06:55:01.498
# 376          78832  Fall 23 DDM MS Form B  10/03/2023  08:17:27.958
# 417          78832  Fall 23 DDM MS Form B  10/31/2023  11:38:48.780
# 574          74983  Fall 23 DDM MS Form B  09/25/2023  07:49:29.105
# ...            ...                    ...         ...           ...
# 114669       91360  Fall 23 DDM MS Form A  11/08/2023  20:53:34.023
# 115691       91544  Fall 23 DDM MS Form B  11/07/2023  08:42:26.689
# 115731       91544  Fall 23 DDM MS Form B  11/27/2023  08:48:44.301
# 116116       89775  Fall 23 DDM MS Form A  11/02/2023  11:34:52.774
# 116157       89775  Fall 23 DDM MS Form A  11/07/2023  11:09:38.247
#
#                                                 Action
# 180     Begin activity Fall 2023 MS DDM Administration
# 221       End activity Fall 2023 MS DDM Administration
# 376     Begin activity Fall 2023 MS DDM Administration
# 417       End activity Fall 2023 MS DDM Administration
# 574     Begin activity Fall 2023 MS DDM Administration
# ...                                                ...
# 114669    End activity Fall 2023 MS DDM Administration
# 115691  Begin activity Fall 2023 MS DDM Administration
# 115731    End activity Fall 2023 MS DDM Administration
# 116116  Begin activity Fall 2023 MS DDM Administration
# 116157    End activity Fall 2023 MS DDM Administration
#
# [842 rows x 5 columns]

# %%
#Full Dataframe of Students where their begin and end activity are different
filtered_df_2 = filtered_groups
filtered_df_2
# Out:
#         Assignment             Activities        Date          Time  \
# 180          74955  Fall 23 DDM MS Form A  09/25/2023  06:21:51.608
# 181          74955  Fall 23 DDM MS Form A  09/25/2023  06:21:53.166
# 182          74955  Fall 23 DDM MS Form A  09/25/2023  06:24:25.468
# 183          74955  Fall 23 DDM MS Form A  09/25/2023  06:24:27.165
# 184          74955  Fall 23 DDM MS Form A  09/25/2023  06:24:46.620
# ...            ...                    ...         ...           ...
# 116153       89775  Fall 23 DDM MS Form A  11/07/2023  11:08:35.644
# 116154       89775  Fall 23 DDM MS Form A  11/07/2023  11:09:23.436
# 116155       89775  Fall 23 DDM MS Form A  11/07/2023  11:09:25.958
# 116156       89775  Fall 23 DDM MS Form A  11/07/2023  11:09:33.793
# 116157       89775  Fall 23 DDM MS Form A  11/07/2023  11:09:38.247
#
#                                                 Action
# 180     Begin activity Fall 2023 MS DDM Administration
# 181                                      Page 1 Loaded
# 182                        Page next clicked on page 1
# 183                                      Page 2 Loaded
# 184                        Page next clicked on page 2
# ...                                                ...
# 116153                                  Page 17 Loaded
# 116154                    Page next clicked on page 17
# 116155                                  Page 18 Loaded
# 116156                    Page next clicked on page 18
# 116157    End activity Fall 2023 MS DDM Administration
#
# [18332 rows x 5 columns]

# %%
#Combining the two dataframes that eventually will be dropped
combined_df = pd.concat([filtered_df, filtered_df_2]).drop_duplicates()
combined_df
# Out:
#         Assignment             Activities        Date          Time  \
# 74           83978  Fall 23 DDM MS Form B  10/23/2023  07:12:18.301
# 75           83978  Fall 23 DDM MS Form B  10/23/2023  07:12:18.661
# 76           83978  Fall 23 DDM MS Form B  10/23/2023  07:12:25.966
# 77           83978  Fall 23 DDM MS Form B  10/23/2023  07:12:26.631
# 78           83978  Fall 23 DDM MS Form B  10/23/2023  07:12:43.755
# ...            ...                    ...         ...           ...
# 116153       89775  Fall 23 DDM MS Form A  11/07/2023  11:08:35.644
# 116154       89775  Fall 23 DDM MS Form A  11/07/2023  11:09:23.436
# 116155       89775  Fall 23 DDM MS Form A  11/07/2023  11:09:25.958
# 116156       89775  Fall 23 DDM MS Form A  11/07/2023  11:09:33.793
# 116157       89775  Fall 23 DDM MS Form A  11/07/2023  11:09:38.247
#
#                                                 Action
# 74      Begin activity Fall 2023 MS DDM Administration
# 75                                       Page 1 Loaded
# 76                         Page next clicked on page 1
# 77                                       Page 2 Loaded
# 78                         Page next clicked on page 2
# ...                                                ...
# 116153                                  Page 17 Loaded
# 116154                    Page next clicked on page 17
# 116155                                  Page 18 Loaded
# 116156                    Page next clicked on page 18
# 116157    End activity Fall 2023 MS DDM Administration
#
# [30495 rows x 5 columns]

# %%
#DATAFRAME OF STUDENTS AFTER DROPPING STUDENTS WHOSE BEGINNING AND END DATES ARE DIFFERENT
#AND DROPPING STUDENTS WHO DON'T HAVE AN END ACTIVITY 
#drops the rows from the dataframe containing different dates for assignments.
combined = pd.concat([ddm_ms_csv, combined_df])

result = combined.drop_duplicates(keep=False)
result
result_df = (result.reset_index()).drop("index", axis = 1)
result_df
# Out:
#        Assignment             Activities        Date          Time  \
# 0           78738  Fall 23 DDM MS Form B  10/03/2023  07:04:18.415
# 1           78738  Fall 23 DDM MS Form B  10/03/2023  07:04:19.771
# 2           78738  Fall 23 DDM MS Form B  10/03/2023  07:04:30.293
# 3           78738  Fall 23 DDM MS Form B  10/03/2023  07:04:31.888
# 4           78738  Fall 23 DDM MS Form B  10/03/2023  07:04:48.403
# ...           ...                    ...         ...           ...
# 89177       91220  Fall 23 DDM MS Form B  11/06/2023  10:56:54.965
# 89178       91220  Fall 23 DDM MS Form B  11/06/2023  10:57:57.090
# 89179       91220  Fall 23 DDM MS Form B  11/06/2023  10:57:58.558
# 89180       91220  Fall 23 DDM MS Form B  11/06/2023  11:01:21.032
# 89181       91220  Fall 23 DDM MS Form B  11/06/2023  11:01:28.192
#
#                                                Action
# 0      Begin activity Fall 2023 MS DDM Administration
# 1                                       Page 1 Loaded
# 2                         Page next clicked on page 1
# 3                                       Page 2 Loaded
# 4                         Page next clicked on page 2
# ...                                               ...
# 89177                                  Page 17 Loaded
# 89178                    Page next clicked on page 17
# 89179                                  Page 18 Loaded
# 89180                    Page next clicked on page 18
# 89181    End activity Fall 2023 MS DDM Administration
#
# [89182 rows x 5 columns]

# %%
#START AND END WITH PAUSE
pause = result_df[result_df["Action"].str.contains("Pause")]
pause_df = pause.drop_duplicates(subset=['Assignment'])
pause_df
# Out:
#        Assignment             Activities        Date          Time  \
# 395         77474  Fall 23 DDM MS Form B  09/29/2023  06:05:10.554
# 1237        75026  Fall 23 DDM MS Form A  09/25/2023  10:43:26.970
# 3549        75185  Fall 23 DDM MS Form A  09/25/2023  11:57:33.580
# 4166        76642  Fall 23 DDM MS Form B  09/27/2023  11:24:57.356
# 4491        79859  Fall 23 DDM MS Form A  10/09/2023  07:13:02.365
# ...           ...                    ...         ...           ...
# 87789       91694  Fall 23 DDM MS Form A  11/07/2023  12:16:19.398
# 87928       91198  Fall 23 DDM MS Form B  11/06/2023  10:42:58.880
# 88670       91206  Fall 23 DDM MS Form A  11/06/2023  10:38:43.301
# 88852       91796  Fall 23 DDM MS Form B  11/07/2023  17:13:36.699
# 88999       92194  Fall 23 DDM MS Form A  11/10/2023  14:28:00.372
#
#                                                Action
# 395    Pause activity Fall 2023 MS DDM Administration
# 1237   Pause activity Fall 2023 MS DDM Administration
# 3549   Pause activity Fall 2023 MS DDM Administration
# 4166   Pause activity Fall 2023 MS DDM Administration
# 4491   Pause activity Fall 2023 MS DDM Administration
# ...                                               ...
# 87789  Pause activity Fall 2023 MS DDM Administration
# 87928  Pause activity Fall 2023 MS DDM Administration
# 88670  Pause activity Fall 2023 MS DDM Administration
# 88852  Pause activity Fall 2023 MS DDM Administration
# 88999  Pause activity Fall 2023 MS DDM Administration
#
# [112 rows x 5 columns]

# %%
#DATAFRAME OF STUDENTS WHO STARTED AND ENDED BUT DIDN'T PAUSE
# Find the 'Assignment' numbers present in pause_df
assignments_to_exclude = pause_df['Assignment']

# Filter out rows in result_df where 'Assignment' numbers appear in pause_df
filtered_result_df = result_df[~result_df['Assignment'].isin(assignments_to_exclude)]
filter_result_df = (filtered_result_df.reset_index()).drop("index", axis = 1)
filter_result_df
# Out:
#        Assignment             Activities        Date          Time  \
# 0           78738  Fall 23 DDM MS Form B  10/03/2023  07:04:18.415
# 1           78738  Fall 23 DDM MS Form B  10/03/2023  07:04:19.771
# 2           78738  Fall 23 DDM MS Form B  10/03/2023  07:04:30.293
# 3           78738  Fall 23 DDM MS Form B  10/03/2023  07:04:31.888
# 4           78738  Fall 23 DDM MS Form B  10/03/2023  07:04:48.403
# ...           ...                    ...         ...           ...
# 84343       91220  Fall 23 DDM MS Form B  11/06/2023  10:56:54.965
# 84344       91220  Fall 23 DDM MS Form B  11/06/2023  10:57:57.090
# 84345       91220  Fall 23 DDM MS Form B  11/06/2023  10:57:58.558
# 84346       91220  Fall 23 DDM MS Form B  11/06/2023  11:01:21.032
# 84347       91220  Fall 23 DDM MS Form B  11/06/2023  11:01:28.192
#
#                                                Action
# 0      Begin activity Fall 2023 MS DDM Administration
# 1                                       Page 1 Loaded
# 2                         Page next clicked on page 1
# 3                                       Page 2 Loaded
# 4                         Page next clicked on page 2
# ...                                               ...
# 84343                                  Page 17 Loaded
# 84344                    Page next clicked on page 17
# 84345                                  Page 18 Loaded
# 84346                    Page next clicked on page 18
# 84347    End activity Fall 2023 MS DDM Administration
#
# [84348 rows x 5 columns]

# %%
#Number of students who never paused on the same day
unique_filter = len(filter_result_df["Assignment"].unique())
unique_filter
# Out:
# 2129

# %%
#Number of Students Who Paused: Using the Modified Dataframe
pause = result_df[result_df["Action"].str.contains("Pause")]
unique_pause = len(pause["Assignment"].unique())
unique_pause
# Out:
# 112

# %%
#ONE SITTING (NO PAUSE) 
#Looking at Completion Times after dropping data with different Begin and End, and no pause
filter_result_df['DateTime'] = pd.to_datetime(filter_result_df['Date'] + ' ' + filter_result_df['Time'])

completion_times = []

for assignment, group in filter_result_df.groupby('Assignment'):
    begin_activity = group[group['Action'] == "Begin activity Fall 2023 MS DDM Administration"]['DateTime']
    end_activity = group[group['Action'] == "End activity Fall 2023 MS DDM Administration"]['DateTime']
    activity_name = group['Activities'].iloc[0]
    
    if not begin_activity.empty and not end_activity.empty:
        start_time = begin_activity.iloc[0]
        end_time = end_activity.iloc[0]
        
        completion_time = end_time - start_time
        completion_times.append((assignment, completion_time, activity_name))

pause_times_df = pd.DataFrame(completion_times, columns=['Assignment', 'Completion Time', 'Activities'])
pause_times_df
# Out:
#       Assignment        Completion Time             Activities
# 0          75021 0 days 00:11:40.313000  Fall 23 DDM MS Form B
# 1          75023 0 days 00:20:56.718000  Fall 23 DDM MS Form B
# 2          75024 0 days 00:27:51.208000  Fall 23 DDM MS Form A
# 3          75025 0 days 00:13:31.400000  Fall 23 DDM MS Form B
# 4          75027 0 days 00:24:50.162000  Fall 23 DDM MS Form B
# ...          ...                    ...                    ...
# 2124       91799 0 days 00:08:07.605000  Fall 23 DDM MS Form A
# 2125       91800 0 days 00:11:47.599000  Fall 23 DDM MS Form B
# 2126       91912 0 days 00:05:09.352000  Fall 23 DDM MS Form A
# 2127       92211 0 days 00:20:49.316000  Fall 23 DDM MS Form B
# 2128       92248 0 days 00:09:48.515000  Fall 23 DDM MS Form A
#
# [2129 rows x 3 columns]

# %%
filtered_pause_times = pause_times_df.sort_values(by="Completion Time", ascending = False)
filtered_pause_time = (filtered_pause_times.reset_index()).drop("index", axis = 1)
filtered_pause_time
# Out:
#       Assignment        Completion Time             Activities
# 0          90875 0 days 08:09:39.175000  Fall 23 DDM MS Form B
# 1          86914 0 days 07:03:48.566000  Fall 23 DDM MS Form B
# 2          82374 0 days 06:52:20.890000  Fall 23 DDM MS Form A
# 3          80907 0 days 06:33:24.677000  Fall 23 DDM MS Form A
# 4          91307 0 days 05:48:11.995000  Fall 23 DDM MS Form B
# ...          ...                    ...                    ...
# 2124       80266 0 days 00:02:55.327000  Fall 23 DDM MS Form A
# 2125       86070 0 days 00:02:52.544000  Fall 23 DDM MS Form B
# 2126       91695 0 days 00:02:32.561000  Fall 23 DDM MS Form B
# 2127       91661 0 days 00:02:20.696000  Fall 23 DDM MS Form A
# 2128       91722 0 days 00:02:08.563000  Fall 23 DDM MS Form A
#
# [2129 rows x 3 columns]

# %%
form_pause_a = filtered_pause_time[filtered_pause_time["Activities"] == "Fall 23 DDM MS Form A"]
form_pause_a
# Out:
#       Assignment        Completion Time             Activities
# 2          82374 0 days 06:52:20.890000  Fall 23 DDM MS Form A
# 3          80907 0 days 06:33:24.677000  Fall 23 DDM MS Form A
# 7          80975 0 days 03:51:55.186000  Fall 23 DDM MS Form A
# 8          76757 0 days 01:56:25.421000  Fall 23 DDM MS Form A
# 9          78799 0 days 01:53:57.830000  Fall 23 DDM MS Form A
# ...          ...                    ...                    ...
# 2117       81738 0 days 00:03:44.709000  Fall 23 DDM MS Form A
# 2123       86589 0 days 00:03:01.504000  Fall 23 DDM MS Form A
# 2124       80266 0 days 00:02:55.327000  Fall 23 DDM MS Form A
# 2127       91661 0 days 00:02:20.696000  Fall 23 DDM MS Form A
# 2128       91722 0 days 00:02:08.563000  Fall 23 DDM MS Form A
#
# [1066 rows x 3 columns]

# %%
form_pause_b = filtered_pause_time[filtered_pause_time["Activities"] == "Fall 23 DDM MS Form B"]
form_pause_b
# Out:
#       Assignment        Completion Time             Activities
# 0          90875 0 days 08:09:39.175000  Fall 23 DDM MS Form B
# 1          86914 0 days 07:03:48.566000  Fall 23 DDM MS Form B
# 4          91307 0 days 05:48:11.995000  Fall 23 DDM MS Form B
# 5          78887 0 days 04:31:02.340000  Fall 23 DDM MS Form B
# 6          85240 0 days 04:08:37.353000  Fall 23 DDM MS Form B
# ...          ...                    ...                    ...
# 2120       91662 0 days 00:03:21.843000  Fall 23 DDM MS Form B
# 2121       91634 0 days 00:03:15.582000  Fall 23 DDM MS Form B
# 2122       82227 0 days 00:03:05.535000  Fall 23 DDM MS Form B
# 2125       86070 0 days 00:02:52.544000  Fall 23 DDM MS Form B
# 2126       91695 0 days 00:02:32.561000  Fall 23 DDM MS Form B
#
# [1063 rows x 3 columns]

# %%
form_pause_a.describe()
# Out:
#          Assignment            Completion Time
# count   1066.000000                       1066
# mean   83833.871482  0 days 00:20:02.483808630
# std     4094.428461  0 days 00:20:24.335168916
# min    75024.000000     0 days 00:02:08.563000
# 25%    81841.500000     0 days 00:12:51.540000
# 50%    83648.000000     0 days 00:17:41.066500
# 75%    86197.000000     0 days 00:23:24.554750
# max    92248.000000     0 days 06:52:20.890000

# %%
a_percentile_90 = form_pause_a["Completion Time"].quantile(0.9)
a_percentile_90
# Out:
# Timedelta('0 days 00:30:01.720000')

# %%
form_pause_a["Completion Time"].median()
# Out:
# Timedelta('0 days 00:17:41.066500')

# %%
form_pause_b.describe()
# Out:
#          Assignment            Completion Time
# count   1063.000000                       1063
# mean   83763.480715  0 days 00:19:37.664866415
# std     4144.531835  0 days 00:25:33.511632513
# min    75021.000000     0 days 00:02:32.561000
# 25%    81738.000000     0 days 00:12:21.285500
# 50%    83628.000000     0 days 00:16:35.213000
# 75%    86197.500000     0 days 00:22:15.557500
# max    92211.000000     0 days 08:09:39.175000

# %%
b_percentile_90 = form_pause_b["Completion Time"].quantile(0.9)
b_percentile_90
# Out:
# Timedelta('0 days 00:28:46.681000')

# %%
form_pause_b["Completion Time"].median()
# Out:
# Timedelta('0 days 00:16:35.213000')

# %%
#NO PAUSE Boxplot of Form A & B: Using Melinee's Code to have similar boxplot style
import matplotlib.pyplot as plt

just_pause_and_ct = filtered_pause_time[['Activities','Completion Time']].reset_index()
just_pause_and_ct['Completion Time'] = [td.total_seconds()/3600 for td in just_pause_and_ct['Completion Time']]
just_pause_and_ct.boxplot(column = 'Completion Time', by = 'Activities', figsize=(12,4), vert=False)
#plt.title('Completion Times per Activity')
plt.xlabel('Completion Time in Hours')
plt.axvline(x=1, color='b', linestyle='--', label='1 Hour Mark')
plt.ylabel('Activities')
plt.show()

# %%
#Looking at Completion Times after dropping data with different Begin and End, and no end
result_df['DateTime'] = pd.to_datetime(result_df['Date'] + ' ' + result_df['Time'])

completion_times = []

for assignment, group in result_df.groupby('Assignment'):
    begin_activity = group[group['Action'] == "Begin activity Fall 2023 MS DDM Administration"]['DateTime']
    end_activity = group[group['Action'] == "End activity Fall 2023 MS DDM Administration"]['DateTime']
    activity_name = group['Activities'].iloc[0]
    
    if not begin_activity.empty and not end_activity.empty:
        start_time = begin_activity.iloc[0]
        end_time = end_activity.iloc[0]
        
        completion_time = end_time - start_time
        completion_times.append((assignment, completion_time, activity_name))

completion_times_df = pd.DataFrame(completion_times, columns=['Assignment', 'Completion Time', 'Activities'])
completion_times_df
# Out:
#       Assignment        Completion Time             Activities
# 0          75021 0 days 00:11:40.313000  Fall 23 DDM MS Form B
# 1          75023 0 days 00:20:56.718000  Fall 23 DDM MS Form B
# 2          75024 0 days 00:27:51.208000  Fall 23 DDM MS Form A
# 3          75025 0 days 00:13:31.400000  Fall 23 DDM MS Form B
# 4          75026 0 days 00:11:24.462000  Fall 23 DDM MS Form A
# ...          ...                    ...                    ...
# 2236       91800 0 days 00:11:47.599000  Fall 23 DDM MS Form B
# 2237       91912 0 days 00:05:09.352000  Fall 23 DDM MS Form A
# 2238       92194 0 days 00:27:04.453000  Fall 23 DDM MS Form A
# 2239       92211 0 days 00:20:49.316000  Fall 23 DDM MS Form B
# 2240       92248 0 days 00:09:48.515000  Fall 23 DDM MS Form A
#
# [2241 rows x 3 columns]

# %%
#Dataframe of the sorted times between start and end of activity
filtered_times = completion_times_df.sort_values(by="Completion Time", ascending = False)
filtered_comp_time = (filtered_times.reset_index()).drop("index", axis = 1)
filtered_comp_time
# Out:
#       Assignment        Completion Time             Activities
# 0          90976 0 days 08:32:38.806000  Fall 23 DDM MS Form B
# 1          90875 0 days 08:09:39.175000  Fall 23 DDM MS Form B
# 2          80860 0 days 07:28:53.904000  Fall 23 DDM MS Form A
# 3          86914 0 days 07:03:48.566000  Fall 23 DDM MS Form B
# 4          82374 0 days 06:52:20.890000  Fall 23 DDM MS Form A
# ...          ...                    ...                    ...
# 2236       80266 0 days 00:02:55.327000  Fall 23 DDM MS Form A
# 2237       86070 0 days 00:02:52.544000  Fall 23 DDM MS Form B
# 2238       91695 0 days 00:02:32.561000  Fall 23 DDM MS Form B
# 2239       91661 0 days 00:02:20.696000  Fall 23 DDM MS Form A
# 2240       91722 0 days 00:02:08.563000  Fall 23 DDM MS Form A
#
# [2241 rows x 3 columns]

# %%
form_a = filtered_comp_time[filtered_comp_time["Activities"] == "Fall 23 DDM MS Form A"]
form_a
# Out:
#       Assignment        Completion Time             Activities
# 2          80860 0 days 07:28:53.904000  Fall 23 DDM MS Form A
# 4          82374 0 days 06:52:20.890000  Fall 23 DDM MS Form A
# 5          80907 0 days 06:33:24.677000  Fall 23 DDM MS Form A
# 10         80975 0 days 03:51:55.186000  Fall 23 DDM MS Form A
# 11         81741 0 days 02:00:31.565000  Fall 23 DDM MS Form A
# ...          ...                    ...                    ...
# 2231       86487 0 days 00:03:31.554000  Fall 23 DDM MS Form A
# 2235       86589 0 days 00:03:01.504000  Fall 23 DDM MS Form A
# 2236       80266 0 days 00:02:55.327000  Fall 23 DDM MS Form A
# 2239       91661 0 days 00:02:20.696000  Fall 23 DDM MS Form A
# 2240       91722 0 days 00:02:08.563000  Fall 23 DDM MS Form A
#
# [1123 rows x 3 columns]

# %%
form_b = filtered_comp_time[filtered_comp_time["Activities"] == "Fall 23 DDM MS Form B"]
form_b
# Out:
#       Assignment        Completion Time             Activities
# 0          90976 0 days 08:32:38.806000  Fall 23 DDM MS Form B
# 1          90875 0 days 08:09:39.175000  Fall 23 DDM MS Form B
# 3          86914 0 days 07:03:48.566000  Fall 23 DDM MS Form B
# 6          91307 0 days 05:48:11.995000  Fall 23 DDM MS Form B
# 7          78887 0 days 04:31:02.340000  Fall 23 DDM MS Form B
# ...          ...                    ...                    ...
# 2232       91662 0 days 00:03:21.843000  Fall 23 DDM MS Form B
# 2233       91634 0 days 00:03:15.582000  Fall 23 DDM MS Form B
# 2234       82227 0 days 00:03:05.535000  Fall 23 DDM MS Form B
# 2237       86070 0 days 00:02:52.544000  Fall 23 DDM MS Form B
# 2238       91695 0 days 00:02:32.561000  Fall 23 DDM MS Form B
#
# [1118 rows x 3 columns]

# %%
filtered_comp_time['Activities'] = filtered_comp_time['Activities'].str.extract('(MS Form [AB])')
filtered_comp_time.head()
# Out:
#    Assignment        Completion Time Activities
# 0       90976 0 days 08:32:38.806000  MS Form B
# 1       90875 0 days 08:09:39.175000  MS Form B
# 2       80860 0 days 07:28:53.904000  MS Form A
# 3       86914 0 days 07:03:48.566000  MS Form B
# 4       82374 0 days 06:52:20.890000  MS Form A

# %%
#Boxplot of Form A & B: Using Melinee's Code to have similar boxplot style
just_act_and_ct = filtered_comp_time[['Activities','Completion Time']].reset_index()
just_act_and_ct['Completion Time'] = [td.total_seconds()/3600 for td in just_act_and_ct['Completion Time']]
just_act_and_ct.boxplot(column = 'Completion Time', by = 'Activities', figsize=(12,4), vert=False)
plt.title('Completion Times per Activity')
plt.xlabel('Completion Time in Hours')
plt.axvline(x=1, color='b', linestyle='--', label='1 Hour Mark')
plt.ylabel('Activities')
plt.show()

# %%
form_a.describe()
# Out:
#          Assignment            Completion Time
# count   1123.000000                       1123
# mean   83874.734639  0 days 00:20:38.342033837
# std     4125.695639  0 days 00:24:01.399061596
# min    75024.000000     0 days 00:02:08.563000
# 25%    81842.000000     0 days 00:13:04.503000
# 50%    83672.000000     0 days 00:17:48.121000
# 75%    86260.500000     0 days 00:23:35.793500
# max    92248.000000     0 days 07:28:53.904000

# %%
form_b.describe()
# Out:
#          Assignment            Completion Time
# count   1118.000000                       1118
# mean   83798.293381  0 days 00:20:29.823859570
# std     4167.665831  0 days 00:30:03.381308687
# min    75021.000000     0 days 00:02:32.561000
# 25%    81735.500000     0 days 00:12:26.543750
# 50%    83631.000000     0 days 00:16:43.180500
# 75%    86254.500000     0 days 00:22:40.766500
# max    92211.000000     0 days 08:32:38.806000

# %%
form_a_median = form_a["Completion Time"].median()
form_a_median
# Out:
# Timedelta('0 days 00:17:48.121000')

# %%
form_b_median = form_b["Completion Time"].median()
form_b_median
# Out:
# Timedelta('0 days 00:16:43.180500')
